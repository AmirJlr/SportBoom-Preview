# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  14.6  1.0  0.0   0.0
# 1  Leicester City  ...  Match Report    NaN  19.0  7.0  13.0  0.0  0.0   0.0
# 2     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.8  0.0  0.0   0.0
# 3          Fulham  ...  Match Report    NaN  22.0  8.0  15.5  1.0  0.0   0.0
# 4     Aston Villa  ...  Match Report    NaN  22.0  8.0  16.3  1.0  0.0   0.0
#
#    season     team
# ...

# %%
matches.shape
# Out:
# (1048, 27)

# %%
# 2 seasons * 20 squads * 38 matches

2 * 20 * 38
# Out:
# 1520

# %%
# Missing Liverpool 2021-2022
matches["team"].value_counts()
# Out:
# Leicester City              53
# Newcastle United            53
# Tottenham Hotspur           53
# Wolverhampton Wanderers     53
# Southampton                 53
# Everton                     53
# West Ham United             53
# Brentford                   53
# Manchester City             52
# Aston Villa                 52
# Leeds United                52
# Arsenal                     52
# Crystal Palace              52
# Chelsea                     52
# Liverpool                   52
# Brighton and Hove Albion    51
# Manchester United           51
# Burnley                     38
# Watford                     38
# Norwich City                38
# Bournemouth                 15
# Nottingham Forest           15
# Fulham                      14
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2021-08-14  17:30  Premier League   Matchweek 1  Sat  Away      W  3.0
# 1   2021-08-21  12:30  Premier League   Matchweek 2  Sat  Home      W  2.0
# 2   2021-08-28  17:30  Premier League   Matchweek 3  Sat  Home      D  1.0
# 3   2021-09-12  16:30  Premier League   Matchweek 4  Sun  Away      W  3.0
# 5   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# 7   2021-09-25  17:30  Premier League   Matchweek 6  Sat  Away      D  3.0
# 9   2021-10-03  16:30  Premier League   Matchweek 7  Sun  Home      D  2.0
# 10  2021-10-16  12:30  Premier League   Matchweek 8  Sat  Away      W  5.0
# 12  2021-10-24  16:30  Premier League   Matchweek 9  Sun  Away      W  5.0
# 14  2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      D  2.0
# 16  2021-11-07  16:30  Premier League  Matchweek 11  Sun  Away      L  2.0
# ...

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     40
# Matchweek 3     40
# Matchweek 4     40
# Matchweek 5     40
# Matchweek 6     40
# Matchweek 2     40
# Matchweek 9     40
# Matchweek 10    40
# Matchweek 11    40
# Matchweek 13    40
# Matchweek 14    40
# Matchweek 15    40
# Matchweek 12    38
# Matchweek 16    36
# Matchweek 8     34
# Matchweek 27    20
# Matchweek 37    20
# Matchweek 33    20
# Matchweek 36    20
# Matchweek 35    20
# Matchweek 34    20
# Matchweek 30    20
# Matchweek 32    20
# Matchweek 31    20
# Matchweek 29    20
# Matchweek 28    20
# Matchweek 20    20
# Matchweek 26    20
# Matchweek 25    20
# Matchweek 24    20
# Matchweek 23    20
# Matchweek 22    20
# Matchweek 21    20
# Matchweek 19    20
# Matchweek 18    20
# Matchweek 17    20
# Matchweek 7     20
# Matchweek 38    20
# Name: round, dtype: int64

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1048 entries, 0 to 42
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1048 non-null   object
#  1   time          1048 non-null   object
#  2   comp          1048 non-null   object
#  3   round         1048 non-null   object
#  4   day           1048 non-null   object
#  5   venue         1048 non-null   object
#  6   result        1048 non-null   object
#  7   gf            1048 non-null   float64
#  8   ga            1048 non-null   float64
#  9   opponent      1048 non-null   object
#  10  xg            1048 non-null   float64
#  11  xga           1048 non-null   float64
#  12  poss          1048 non-null   float64
#  13  attendance    1044 non-null   float64
#  14  captain       1048 non-null   object
#  15  formation     1048 non-null   object
#  16  referee       1048 non-null   object
#  17  match report  1048 non-null   object
# ...

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 0  2022-08-05  20:00   Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00   Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30   Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30   Matchweek 5  Wed  Home      W  2.0  1.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2022-04-30  15:00  Matchweek 35  Sat  Away      L  0.0  2.0
# 39 2022-05-08  14:00  Matchweek 36  Sun  Home      L  0.0  4.0
# 40 2022-05-11  19:45  Matchweek 21  Wed  Away      L  0.0  3.0
# 41 2022-05-15  14:00  Matchweek 37  Sun  Away      D  1.0  1.0
# 42 2022-05-22  16:00  Matchweek 38  Sun  Home      L  0.0  5.0
#
#           opponent   xg  ...  match report    sh  sot  dist   fk   pk pkatt  \
# 0   Crystal Palace  1.0  ...  Match Report  10.0  2.0  14.6  1.0  0.0   0.0
# ...

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 0  2022-08-05  20:00   Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00   Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30   Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30   Matchweek 5  Wed  Home      W  2.0  1.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2022-04-30  15:00  Matchweek 35  Sat  Away      L  0.0  2.0
# 39 2022-05-08  14:00  Matchweek 36  Sun  Home      L  0.0  4.0
# 40 2022-05-11  19:45  Matchweek 21  Wed  Away      L  0.0  3.0
# 41 2022-05-15  14:00  Matchweek 37  Sun  Away      D  1.0  1.0
# 42 2022-05-22  16:00  Matchweek 38  Sun  Home      L  0.0  5.0
#
#           opponent   xg  ...   fk   pk  pkatt season          team target  \
# 0   Crystal Palace  1.0  ...  1.0  0.0    0.0   2022       Arsenal      1
# ...

# %%
from sklearn.svm import SVC

# %%
svm = SVC()

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
train
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 16 2021-12-05  14:00  Matchweek 15  Sun  Away      L  0.0  3.0
# 17 2021-12-11  17:30  Matchweek 16  Sat  Home      L  0.0  1.0
# 18 2021-12-14  19:45  Matchweek 17  Tue  Home      L  0.0  2.0
# 19 2021-12-26  15:00  Matchweek 19  Sun  Home      L  0.0  5.0
# 20 2021-12-28  15:00  Matchweek 20  Tue  Away      L  0.0  3.0
#
#           opponent   xg  ...   fk   pk  pkatt season             team target  \
# 1        Tottenham  2.0  ...  1.0  0.0    0.0   2021  Manchester City      0
# ...

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
test
# Out:
#          date   time         round  day venue result   gf   ga  \
# 0  2022-08-05  20:00   Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00   Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30   Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30   Matchweek 5  Wed  Home      W  2.0  1.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2022-04-30  15:00  Matchweek 35  Sat  Away      L  0.0  2.0
# 39 2022-05-08  14:00  Matchweek 36  Sun  Home      L  0.0  4.0
# 40 2022-05-11  19:45  Matchweek 21  Wed  Away      L  0.0  3.0
# 41 2022-05-15  14:00  Matchweek 37  Sun  Away      D  1.0  1.0
# 42 2022-05-22  16:00  Matchweek 38  Sun  Home      L  0.0  5.0
#
#           opponent   xg  ...   fk   pk  pkatt season          team target  \
# 0   Crystal Palace  1.0  ...  1.0  0.0    0.0   2022       Arsenal      1
# ...

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
svm.fit(train[predictors], train["target"])
# Out:
# SVC()

# %%
svm_preds = svm.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
accuracy = accuracy_score(test["target"], svm_preds)

# %%
accuracy
# Out:
# 0.6079881656804734

# %%
cm = confusion_matrix(test["target"], svm_preds)
cm
# Out:
# array([[411,   0],
#        [265,   0]], dtype=int64)

# %%
disp = ConfusionMatrixDisplay(cm, display_labels=svm.classes_)
disp.plot()

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=svm_preds))

# %%
combined
# Out:
#     actual  predicted
# 0        1          0
# 1        1          0
# 2        1          0
# 3        1          0
# 4        1          0
# ..     ...        ...
# 38       0          0
# 39       0          0
# 40       0          0
# 41       0          0
# 42       0          0
#
# [676 rows x 2 columns]

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0
# actual
# 0          411
# 1          265

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
group
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# 8  2021-09-25  12:30   Matchweek 6  Sat  Away      W  1.0  0.0
# 10 2021-10-03  16:30   Matchweek 7  Sun  Away      D  2.0  2.0
# 11 2021-10-16  15:00   Matchweek 8  Sat  Home      W  2.0  0.0
# 13 2021-10-23  17:30   Matchweek 9  Sat  Away      W  4.0  1.0
# 15 2021-10-30  15:00  Matchweek 10  Sat  Home      L  0.0  2.0
# 17 2021-11-06  12:30  Matchweek 11  Sat  Away      W  2.0  0.0
# 18 2021-11-21  14:00  Matchweek 12  Sun  Home      W  3.0  0.0
# 20 2021-11-28  14:00  Matchweek 13  Sun  Home      W  2.0  1.0
# 21 2021-12-01  20:15  Matchweek 14  Wed  Away      W  2.0  1.0
# ...

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga  \
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# 8  2021-09-25  12:30   Matchweek 6  Sat  Away      W  1.0  0.0
# 10 2021-10-03  16:30   Matchweek 7  Sun  Away      D  2.0  2.0
# 11 2021-10-16  15:00   Matchweek 8  Sat  Home      W  2.0  0.0
# 13 2021-10-23  17:30   Matchweek 9  Sat  Away      W  4.0  1.0
# 15 2021-10-30  15:00  Matchweek 10  Sat  Home      L  0.0  2.0
# 17 2021-11-06  12:30  Matchweek 11  Sat  Away      W  2.0  0.0
# 18 2021-11-21  14:00  Matchweek 12  Sun  Home      W  3.0  0.0
# 20 2021-11-28  14:00  Matchweek 13  Sun  Home      W  2.0  1.0
# 21 2021-12-01  20:15  Matchweek 14  Wed  Away      W  2.0  1.0
# 22 2021-12-04  17:30  Matchweek 15  Sat  Away      W  3.0  1.0
# 24 2021-12-11  12:30  Matchweek 16  Sat  Home      W  1.0  0.0
# 25 2021-12-14  20:00  Matchweek 17  Tue  Home      W  7.0  0.0
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time         round  day venue result  \
# team
# Arsenal                 4  2021-09-11  15:00   Matchweek 4  Sat  Home      W
#                         5  2021-09-18  15:00   Matchweek 5  Sat  Away      W
#                         7  2021-09-26  16:30   Matchweek 6  Sun  Home      W
#                         8  2021-10-02  17:30   Matchweek 7  Sat  Away      D
#                         9  2021-10-18  20:00   Matchweek 8  Mon  Home      D
# ...                               ...    ...           ...  ...   ...    ...
# Wolverhampton Wanderers 11 2022-10-18  20:15  Matchweek 12  Tue  Away      L
#                         12 2022-10-23  14:00  Matchweek 13  Sun  Home      L
#                         13 2022-10-29  15:00  Matchweek 14  Sat  Away      D
#                         14 2022-11-05  15:00  Matchweek 15  Sat  Home      L
#                         16 2022-11-12  19:45  Matchweek 16  Sat  Home      L
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time         round  day venue result   gf   ga  \
# 4  2021-09-11  15:00   Matchweek 4  Sat  Home      W  1.0  0.0
# 5  2021-09-18  15:00   Matchweek 5  Sat  Away      W  1.0  0.0
# 7  2021-09-26  16:30   Matchweek 6  Sun  Home      W  3.0  1.0
# 8  2021-10-02  17:30   Matchweek 7  Sat  Away      D  0.0  0.0
# 9  2021-10-18  20:00   Matchweek 8  Mon  Home      D  2.0  2.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 11 2022-10-18  20:15  Matchweek 12  Tue  Away      L  1.0  2.0
# 12 2022-10-23  14:00  Matchweek 13  Sun  Home      L  0.0  4.0
# 13 2022-10-29  15:00  Matchweek 14  Sat  Away      D  1.0  1.0
# 14 2022-11-05  15:00  Matchweek 15  Sat  Home      L  2.0  3.0
# 16 2022-11-12  19:45  Matchweek 16  Sat  Home      L  0.0  2.0
#
#           opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 4     Norwich City  3.2  ...    15         5    0.000000   3.000000
# 5          Burnley  1.0  ...    15         5    0.333333   2.333333
# ...

# %%
matches_rolling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 979 entries, 4 to 16
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           979 non-null    datetime64[ns]
#  1   time           979 non-null    object
#  2   round          979 non-null    object
#  3   day            979 non-null    object
#  4   venue          979 non-null    object
#  5   result         979 non-null    object
#  6   gf             979 non-null    float64
#  7   ga             979 non-null    float64
#  8   opponent       979 non-null    object
#  9   xg             979 non-null    float64
#  10  xga            979 non-null    float64
#  11  poss           979 non-null    float64
#  12  attendance     975 non-null    float64
#  13  captain        979 non-null    object
#  14  formation      979 non-null    object
#  15  referee        979 non-null    object
#  16  match report   979 non-null    object
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling.head()
# Out:
#         date   time        round  day venue result   gf   ga        opponent  \
# 0 2021-09-11  15:00  Matchweek 4  Sat  Home      W  1.0  0.0    Norwich City
# 1 2021-09-18  15:00  Matchweek 5  Sat  Away      W  1.0  0.0         Burnley
# 2 2021-09-26  16:30  Matchweek 6  Sun  Home      W  3.0  1.0       Tottenham
# 3 2021-10-02  17:30  Matchweek 7  Sat  Away      D  0.0  0.0        Brighton
# 4 2021-10-18  20:00  Matchweek 8  Mon  Home      D  2.0  2.0  Crystal Palace
#
#     xg  ...  hour  day_code  gf_rolling ga_rolling sh_rolling sot_rolling  \
# 0  3.2  ...    15         5    0.000000   3.000000   9.666667    2.333333
# 1  1.0  ...    15         5    0.333333   2.333333  12.333333    3.000000
# 2  1.1  ...    16         6    0.666667   1.666667  14.666667    3.000000
# 3  0.6  ...    17         5    1.666667   0.333333  18.333333    5.333333
# 4  1.9  ...    20         0    1.333333   0.333333  11.000000    4.000000
#
#   dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# ...

# %%
matches_rolling.to_csv('FData.csv')
